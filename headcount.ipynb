# %%
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime
from datetime import date

# %%
df0 = pd.read_csv('data_headcount.csv')
df0.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  847428         Ms.     Walter              D   Goldberg      F
# 1  946350        Mrs.       Lulu              I    Collett      F
# 2  321420        Mrs.      Sybil              P      Bogan      F
# 3  719891       Prof.        Tom              Y     Dingle      M
# 4  999307         Mr.      Daryl              C  Treadwell      M
#
#                         E Mail     Father's Name      Mother's Name  \
# 0      walter.goldberg@aol.com   Alonzo Goldberg    Lashay Goldberg
# 1     lulu.collett@hotmail.com     Arden Collett     Austin Collett
# 2        sybil.bogan@gmail.com     Matthew Bogan    Marquitta Bogan
# 3         tom.dingle@gmail.com  Francesco Dingle     Malissa Dingle
# 4  daryl.treadwell@verizon.net   Moshe Treadwell  Phyllis Treadwell
#
#   Mother's Maiden Name       ...                 SSN    Phone No.   \
# 0               Archie       ...         687-24-6867  209-851-5183
# ...

# %%
list(df0)
# Out:
# ['Emp ID',
#  'Name Prefix',
#  'First Name',
#  'Middle Initial',
#  'Last Name',
#  'Gender',
#  'E Mail',
#  "Father's Name",
#  "Mother's Name",
#  "Mother's Maiden Name",
#  'Date of Birth',
#  'Time of Birth',
#  'Age in Yrs.',
#  'Weight in Kgs.',
#  'Date of Joining',
#  'Quarter of Joining',
#  'Half of Joining',
#  'Year of Joining',
#  'Month of Joining',
#  'Month Name of Joining',
#  'Short Month',
#  'Day of Joining',
#  'DOW of Joining',
#  'Short DOW',
#  'Age in Company (Years)',
#  'Salary',
#  'Last % Hike',
#  'SSN',
#  'Phone No. ',
#  'Place Name',
#  'County',
#  'City',
#  'State',
#  'Zip',
#  'Region',
#  'User Name',
#  'Password']

# %% [markdown]
# # Subset data I want to keep.

# %%
df1 = df0[['Emp ID', 'First Name', 'Last Name', 'Gender', 'E Mail', 'Date of Birth', 'Date of Joining', 'Age in Company (Years)',
       'Salary', 'Last % Hike', 'Place Name', 'County', 'City', 'State', 'Zip']]
list(df1)
# Out:
# ['Emp ID',
#  'First Name',
#  'Last Name',
#  'Gender',
#  'E Mail',
#  'Date of Birth',
#  'Date of Joining',
#  'Age in Company (Years)',
#  'Salary',
#  'Last % Hike',
#  'Place Name',
#  'County',
#  'City',
#  'State',
#  'Zip']

# %%
df1.head()
# Out:
#    Emp ID First Name  Last Name Gender                       E Mail  \
# 0  847428     Walter   Goldberg      F      walter.goldberg@aol.com
# 1  946350       Lulu    Collett      F     lulu.collett@hotmail.com
# 2  321420      Sybil      Bogan      F        sybil.bogan@gmail.com
# 3  719891        Tom     Dingle      M         tom.dingle@gmail.com
# 4  999307      Daryl  Treadwell      M  daryl.treadwell@verizon.net
#
#   Date of Birth Date of Joining  Age in Company (Years)  Salary Last % Hike  \
# 0     1/19/1967       9/30/1991                   25.84   57465          0%
# 1     6/24/1987        6/6/2015                    2.15  102942          1%
# 2     8/21/1964       9/16/1995                   21.88  181051         26%
# 3     11/5/1985      11/27/2010                    6.67   71041         11%
# 4      7/7/1977       4/10/2014                    3.30   87411          6%
#
#   Place Name         County       City State    Zip
# ...

# %% [markdown]
# # Rename variables

# %%
df1.rename(columns={'Emp ID': 'emplId', 'First Name': 'firstName', 'Last Name': 'lastName','Gender': 'gender', 'E Mail': 'eMail',
                   'Date of Birth': 'dob', 'Date of Joining': 'hireDate', 'Age in Company (Years)': 'tenure', 'Salary': 'salary',
                   'Last % Hike':'lastIncrease', 'Place Name': 'workLocation', 'County': 'county', 'State': 'state',
                   'City': 'city', 'Zip': 'zipCode'}, inplace=True)
df1.head()
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\pandas\core\frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#    emplId firstName   lastName gender                        eMail        dob  \
# 0  847428    Walter   Goldberg      F      walter.goldberg@aol.com  1/19/1967
# 1  946350      Lulu    Collett      F     lulu.collett@hotmail.com  6/24/1987
# 2  321420     Sybil      Bogan      F        sybil.bogan@gmail.com  8/21/1964
# 3  719891       Tom     Dingle      M         tom.dingle@gmail.com  11/5/1985
# 4  999307     Daryl  Treadwell      M  daryl.treadwell@verizon.net   7/7/1977
#
#      hireDate  tenure  salary lastIncrease workLocation         county  \
# 0   9/30/1991   25.84   57465           0%    Sunnyvale    Santa Clara
# ...

# %% [markdown]
# # Creating new variables

# %%
df1['domain'] = df1['eMail'].str.split('@').str[1]
df1.head()
# Out:
# C:\Users\David\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    emplId firstName   lastName gender                        eMail        dob  \
# 0  847428    Walter   Goldberg      F      walter.goldberg@aol.com  1/19/1967
# 1  946350      Lulu    Collett      F     lulu.collett@hotmail.com  6/24/1987
# 2  321420     Sybil      Bogan      F        sybil.bogan@gmail.com  8/21/1964
# 3  719891       Tom     Dingle      M         tom.dingle@gmail.com  11/5/1985
# 4  999307     Daryl  Treadwell      M  daryl.treadwell@verizon.net   7/7/1977
#
#      hireDate  tenure  salary lastIncrease workLocation         county  \
# ...

# %% [markdown]
# # Calcuate Age based on current date
